# %%
import matplotlib
matplotlib.use("Agg")
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from pyimagesearch.lenet import LeNet
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2
import os
import matplotlib
import random
import pickle
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
EPOCHS = 25
INIT_LR = 1e-3
BS = 32

# initialize the data and labels
print("[INFO] loading images...")
data = []
labels = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images("images")))
random.seed(42)
random.shuffle(imagePaths)

# loop over the input images
for imagePath in imagePaths:
	# load the image, pre-process it, and store it in the data list
	image = cv2.imread(imagePath)
	image = cv2.resize(image, (28, 28))
	image = img_to_array(image)
	data.append(image)

	# extract the class label from the image path and update the
	# labels list
# 	label = imagePath.split(os.path.sep)[-2]
# 	label = 1 if label == "fire_department" else 0
# 	labels.append(label)
	l = label = imagePath.split(os.path.sep)[-2]
	labels.append(l)
# scale the raw pixel intensities to the range [0, 1]


# print(labels)
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
# le = LabelEncoder() 
# labels = le.fit_transform(labels)
# print(mlb.classes_)
# Out:
# [INFO] loading images...
# ['police', 'vehicle', 'police', 'not_vehicle', 'police', 'not_vehicle', 'vehicle', 'police', 'police', 'fire_department', 'ambulance', 'police', 'fire_department', 'vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'police', 'fire_department', 'vehicle', 'vehicle', 'vehicle', 'ambulance', 'vehicle', 'fire_department', 'ambulance', 'not_vehicle', 'fire_department', 'police', 'vehicle', 'ambulance', 'police', 'fire_department', 'vehicle', 'police', 'vehicle', 'vehicle', 'vehicle', 'police', 'police', 'vehicle', 'police', 'fire_department', 'vehicle', 'vehicle', 'fire_department', 'vehicle', 'fire_department', 'not_vehicle', 'vehicle', 'police', 'ambulance', 'ambulance', 'not_vehicle', 'vehicle', 'police', 'fire_department', 'vehicle', 'vehicle', 'ambulance', 'ambulance', 'vehicle', 'fire_department', 'vehicle', 'police', 'not_vehicle', 'not_vehicle', 'vehicle', 'police', 'vehicle', 'police', 'ambulance', 'not_vehicle', 'ambulance', 'not_vehicle', 'not_vehicle', 'ambulance', 'police', 'vehicle', 'not_vehicle', 'not_vehicle', 'ambulance', 'police', 'vehicle', 'vehicle', 'vehicle', 'police', 'not_vehicle', 'not_vehicle', 'police', 'vehicle', 'ambulance', 'police', 'not_vehicle', 'not_vehicle', 'vehicle', 'ambulance', 'ambulance', 'vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'vehicle', 'police', 'police', 'fire_department', 'vehicle', 'not_vehicle', 'police', 'not_vehicle', 'vehicle', 'ambulance', 'police', 'fire_department', 'ambulance', 'police', 'police', 'police', 'ambulance', 'police', 'fire_department', 'ambulance', 'police', 'police', 'police', 'ambulance', 'vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'not_vehicle', 'vehicle', 'vehicle', 'police', 'vehicle', 'not_vehicle', 'not_vehicle', 'vehicle', 'vehicle', 'vehicle', 'police', 'vehicle', 'vehicle', 'vehicle', 'ambulance', 'ambulance', 'ambulance', 'not_vehicle', 'ambulance', 'not_vehicle', 'fire_department', 'vehicle', 'ambulance', 'police', 'vehicle', 'not_vehicle', 'ambulance', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'police', 'ambulance', 'vehicle', 'vehicle', 'fire_department', 'police', 'not_vehicle', 'not_vehicle', 'ambulance', 'not_vehicle', 'police', 'vehicle', 'vehicle', 'police', 'fire_department', 'police', 'fire_department', 'fire_department', 'not_vehicle', 'vehicle', 'police', 'police', 'vehicle', 'police', 'ambulance', 'not_vehicle', 'not_vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'ambulance', 'not_vehicle', 'vehicle', 'not_vehicle', 'vehicle', 'fire_department', 'vehicle', 'not_vehicle', 'fire_department', 'police', 'vehicle', 'vehicle', 'vehicle', 'fire_department', 'not_vehicle', 'police', 'vehicle', 'police', 'not_vehicle', 'vehicle', 'vehicle', 'vehicle', 'ambulance', 'not_vehicle', 'ambulance', 'police', 'not_vehicle', 'not_vehicle', 'not_vehicle', 'ambulance', 'ambulance', 'police', 'not_vehicle', 'not_vehicle', 'not_vehicle', 'police', 'vehicle', 'not_vehicle', 'not_vehicle', 'not_vehicle', 'vehicle', 'ambulance', 'police', 'fire_department', 'vehicle', 'not_vehicle', 'vehicle', 'not_vehicle', 'police', 'not_vehicle', 'vehicle', 'not_vehicle', 'not_vehicle', 'fire_department', 'vehicle', 'vehicle', 'not_vehicle', 'ambulance', 'vehicle', 'not_vehicle', 'police', 'ambulance', 'not_vehicle', 'police', 'vehicle', 'fire_department', 'not_vehicle', 'not_vehicle', 'not_vehicle', 'not_vehicle', 'vehicle', 'police', 'police', 'ambulance', 'vehicle', 'police', 'police', 'not_vehicle', 'not_vehicle', 'fire_department', 'ambulance', 'vehicle', 'vehicle', 'not_vehicle', 'police', 'vehicle', 'vehicle', 'vehicle', 'ambulance', 'fire_department', 'not_vehicle', 'fire_department', 'ambulance', 'vehicle', 'not_vehicle', 'not_vehicle', 'vehicle', 'ambulance', 'police', 'vehicle', 'police', 'not_vehicle', 'not_vehicle', 'vehicle', 'vehicle', 'not_vehicle', 'vehicle', 'not_vehicle', 'police', 'ambulance', 'police', 'police', 'not_vehicle', 'ambulance', 'not_vehicle', 'vehicle', 'police', 'police', 'not_vehicle', 'ambulance', 'police', ...
# ['ambulance' 'fire_department' 'not_vehicle' 'police' 'vehicle']

# %%
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing

(trainX, testX, trainY, testY) = train_test_split(data,
	labels, test_size=0.25, random_state=42)

# convert the labels from integers to vectors
# trainY = to_categorical(trainY, num_classes=5)
# testY = to_categorical(testY, num_classes=5)


# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,
	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
	horizontal_flip=True, fill_mode="nearest")



# initialize the model
print("[INFO] compiling model...")
model = LeNet.build(width=28, height=28, depth=3, classes=len(mlb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# train the network
print("[INFO] training network...")
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=BS),
	validation_data=(testX, testY), steps_per_epoch=len(trainX) // BS,
	epochs=EPOCHS, verbose=1)

# save the model to disk
print("[INFO] serializing network...")
model.save("EmergencyDetector.model")
print("[INFO] serializing label binarizer...")
f = open("labelbin1", "wb")
f.write(pickle.dumps(mlb,2))
f.close()
# plot the training loss and accuracy
# Out:
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1
# 40/40 [==============================] - 10s 262ms/step - loss: 0.7046 - acc: 0.7258 - val_loss: 0.9246 - val_acc: 0.6551
# Epoch 24/25
# 40/40 [==============================] - 11s 263ms/step - loss: 0.7117 - acc: 0.7258 - val_loss: 0.9132 - val_acc: 0.6690
# Epoch 25/25
# 40/40 [==============================] - 11s 272ms/step - loss: 0.6511 - acc: 0.7532 - val_loss: 0.9675 - val_acc: 0.6759
# [INFO] serializing network...

# %%
# %matplotlib inline
plt.style.use("ggplot")
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy on Emergency Responders/Regular Vehicles")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
display(plt)
plt.savefig("EmergencyDetectPlot")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py'>

# %%
# Out:
# [INFO] serializing label binarizer...

# %%
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.
# absl-py (0.1.12)
# astor (0.6.2)
# bleach (1.5.0)
# certifi (2018.1.18)
# chardet (3.0.4)
# cycler (0.10.0)
# Cython (0.28.1)
# decorator (4.2.1)
# entrypoints (0.2.3)
# gast (0.2.0)
# grpcio (1.10.0)
# h5py (2.7.1)
# html5lib (0.9999999)
# idna (2.6)
# imutils (0.4.6)
# ipykernel (4.8.2)
# ipython (6.2.1)
# ipython-genutils (0.2.0)
# ipywidgets (7.1.2)
# jedi (0.11.1)
# Jinja2 (2.10)
# jsonschema (2.6.0)
# jupyter (1.0.0)
# jupyter-client (5.2.3)
# jupyter-console (5.2.0)
# jupyter-core (4.4.0)
# Keras (2.1.5)
# kiwisolver (1.0.1)
# leveldb (0.194)
# lmdb (0.93)
# Markdown (2.6.11)
# MarkupSafe (1.0)
# matplotlib (2.2.2)
# mistune (0.8.3)
# mpmath (1.0.0)
# nbconvert (5.3.1)
# nbformat (4.4.0)
# networkx (2.1)
# nose (1.3.7)
# notebook (5.4.1)
# numpy (1.14.2)
# pandas (0.22.0)
# pandocfilters (1.4.2)
# parso (0.1.1)
# pexpect (4.4.0)
# pickleshare (0.7.4)
# Pillow (5.0.0)
# pip (9.0.3)
# prompt-toolkit (1.0.15)
# protobuf (3.5.2.post1)
# ptyprocess (0.5.2)
# pycocotools (2.0)
# pydot-ng (1.0.0)
# Pygments (2.2.0)
# pyparsing (2.2.0)
# python-dateutil (2.7.0)
# python-gflags (3.1.2)
# pytz (2018.3)
# PyWavelets (0.5.2)
# PyYAML (3.12)
# pyzmq (17.0.0)
# qtconsole (4.3.1)
# requests (2.18.4)
# scikit-image (0.13.1)
# scikit-learn (0.19.1)
# scipy (1.0.0)
# Send2Trash (1.5.0)
# setuptools (39.0.1)
# simplegeneric (0.8.1)
# six (1.11.0)
# sklearn (0.0)
# sympy (1.1.1)
# tensorboard (1.6.0)
# tensorflow (1.6.0)
# termcolor (1.1.0)
# terminado (0.8.1)
# testpath (0.3.1)
# torch (0.3.1)
# torchvision (0.2.0)
# tornado (5.0.1)
# traitlets (4.3.2)
# urllib3 (1.22)
# wcwidth (0.1.7)
# webencodings (0.5.1)
# Werkzeug (0.14.1)
# wheel (0.30.0)
# widgetsnbextension (3.1.4)

# %%
# Out:
# Collecting pickle
#   Could not find a version that satisfies the requirement pickle (from versions: )
# No matching distribution found for pickle
# You are using pip version 9.0.3, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
